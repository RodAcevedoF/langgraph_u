# %%
import sqlite3
import json
from langchain_core.messages import (
    SystemMessage,
    AIMessage,
    HumanMessage, 
    ToolMessage,
)
from langchain_openai import ChatOpenAI
from langgraph.graph import START, END, StateGraph
from langgraph.graph.message import MessagesState
from langgraph.graph.state import CompiledStateGraph
from langgraph.checkpoint.memory import MemorySaver
from langgraph.checkpoint.sqlite import SqliteSaver
from IPython.display import Image, display

# %%
from dotenv import load_dotenv
load_dotenv()

llm = ChatOpenAI(
    model="gpt-4o-mini",
    temperature=0.0,
)

# %%
def run_graph(query: str, graph: CompiledStateGraph, thread_id: str):
    output = graph.invoke(
        config={"configurable":{"thread_id": thread_id}},
        input={"messages":[HumanMessage(query)]}
    )
    return output

# %% [markdown]
# **In-memory**

# %%
def chatbot(state: MessagesState):
    ai_message = llm.invoke(state["messages"])
    return {"messages": ai_message}


workflow = StateGraph(MessagesState)

workflow.add_node(chatbot)
workflow.add_edge(START, "chatbot")
workflow.add_edge("chatbot", END)

checkpointer = MemorySaver()
in_memory_graph = workflow.compile(checkpointer=checkpointer)

display(
    Image(
        in_memory_graph.get_graph().draw_mermaid_png()
    )
)

# %%
run_graph(
    query="Hi",
    graph=in_memory_graph, 
    thread_id="1"
)
# Out:
# {'messages': [HumanMessage(content='Hi', additional_kwargs={}, response_metadata={}, id='749fdec8-2491-4cf0-8ae4-15fa2da6d49e'),
#   AIMessage(content='Hello! How can I assist you today?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 9, 'prompt_tokens': 8, 'total_tokens': 17, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_a0c7577d81', 'id': 'chatcmpl-DrVjPrSsykbijdysu1OZwuTxisbSq', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019ed25c-6028-7250-b92c-07c6e1cc3730-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 8, 'output_tokens': 9, 'total_tokens': 17, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}

# %%
list(
    in_memory_graph.get_state(
        config={"configurable":{"thread_id": "1"}}
    )
)
# Out:
# [{'messages': [HumanMessage(content='Hi', additional_kwargs={}, response_metadata={}, id='749fdec8-2491-4cf0-8ae4-15fa2da6d49e'),
#    AIMessage(content='Hello! How can I assist you today?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 9, 'prompt_tokens': 8, 'total_tokens': 17, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_a0c7577d81', 'id': 'chatcmpl-DrVjPrSsykbijdysu1OZwuTxisbSq', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019ed25c-6028-7250-b92c-07c6e1cc3730-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 8, 'output_tokens': 9, 'total_tokens': 17, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]},
#  (),
#  {'configurable': {'thread_id': '1',
#    'checkpoint_ns': '',
#    'checkpoint_id': '1f169cb4-d123-61fa-8001-8b1af71d7d5e'}},
#  {'source': 'loop', 'step': 1, 'parents': {}},
#  '2026-06-16T21:35:31.751149+00:00',
#  {'configurable': {'thread_id': '1',
#    'checkpoint_ns': '',
#    'checkpoint_id': '1f169cb4-bed2-61cc-8000-059e8eea5df3'}},
#  (),
#  ()]

# %% [markdown]
# **SQLite**

# %%
# For production, use something like Postgres
db_path = "memory.db"
conn = sqlite3.connect(db_path, check_same_thread=False)

# %%
memory = SqliteSaver(conn)
external_memory_graph = workflow.compile(checkpointer=memory)

display(
    Image(
        external_memory_graph.get_graph().draw_mermaid_png()
    )
)

# %%
run_graph(
    query="What's a memory?",
    graph=external_memory_graph, 
    thread_id="2"
)
# Out:
# {'messages': [HumanMessage(content="What's a memory?", additional_kwargs={}, response_metadata={}, id='1e4da0b8-60a3-40ae-8cf8-534ca6a0663f'),
#   AIMessage(content='A memory is the mental capacity or faculty to store, retain, and subsequently retrieve information and experiences. It encompasses various processes, including encoding (the initial learning of information), storage (maintaining information over time), and retrieval (accessing the information when needed). \n\nMemories can be categorized into different types, such as:\n\n1. **Short-term memory**: Holds a small amount of information for a brief period, typically seconds to minutes.\n2. **Long-term memory**: Stores information for extended periods, ranging from hours to a lifetime. This can be further divided into:\n   - **Explicit (declarative) memory**: Involves conscious recall of facts and events.\n   - **Implicit (non-declarative) memory**: Involves skills and procedures that are performed without conscious awareness.\n\nMemories play a crucial role in shaping our identity, influencing our behavior, and helping us navigate the world. They can be influenced by various factors, including emotions, context, and the passage of time.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 206, 'prompt_tokens': 11, 'total_tokens': 217, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_d3cbb830a7', 'id': 'chatcmpl-DrVjb8K10BXSeH2PrOKWv7edd10mW', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019ed25c-9207-70d1-8ccf-b7cfd96e296c-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 11, 'output_tokens': 206, 'total_tokens': 217, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}

# %%
list(
    external_memory_graph.get_state(
        config={"configurable":{"thread_id": "2"}}
    )
)
# Out:
# [{'messages': [HumanMessage(content="What's a memory?", additional_kwargs={}, response_metadata={}, id='1e4da0b8-60a3-40ae-8cf8-534ca6a0663f'),
#    AIMessage(content='A memory is the mental capacity or faculty to store, retain, and subsequently retrieve information and experiences. It encompasses various processes, including encoding (the initial learning of information), storage (maintaining information over time), and retrieval (accessing the information when needed). \n\nMemories can be categorized into different types, such as:\n\n1. **Short-term memory**: Holds a small amount of information for a brief period, typically seconds to minutes.\n2. **Long-term memory**: Stores information for extended periods, ranging from hours to a lifetime. This can be further divided into:\n   - **Explicit (declarative) memory**: Involves conscious recall of facts and events.\n   - **Implicit (non-declarative) memory**: Involves skills and procedures that are performed without conscious awareness.\n\nMemories play a crucial role in shaping our identity, influencing our behavior, and helping us navigate the world. They can be influenced by various factors, including emotions, context, and the passage of time.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 206, 'prompt_tokens': 11, 'total_tokens': 217, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_d3cbb830a7', 'id': 'chatcmpl-DrVjb8K10BXSeH2PrOKWv7edd10mW', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019ed25c-9207-70d1-8ccf-b7cfd96e296c-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 11, 'output_tokens': 206, 'total_tokens': 217, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]},
#  (),
#  {'configurable': {'thread_id': '2',
#    'checkpoint_ns': '',
#    'checkpoint_id': '1f169cb5-6f1f-63c5-8001-15633f96be43'}},
#  {'source': 'loop', 'step': 1, 'parents': {}},
#  '2026-06-16T21:35:48.317051+00:00',
#  {'configurable': {'thread_id': '2',
#    'checkpoint_ns': '',
#    'checkpoint_id': '1f169cb5-3895-6d6e-8000-c0c35e8e974a'}},
#  (),
#  ()]

# %% [markdown]
# **Querying memory**

# %%
cursor = conn.cursor()
cursor.execute("SELECT name FROM sqlite_master WHERE type='table';")
tables = [table_name[0] for table_name in cursor.fetchall()]
tables
# Out:
# ['checkpoints', 'writes']

# %%
columns_map = []
results = []

for table in tables:
    cursor.execute(f"select * from {table}")
    results.append(cursor.fetchall())
    columns_map.append({table:[desc[0] for desc in cursor.description]})

# %%
columns_map
# Out:
# [{'checkpoints': ['thread_id',
#    'checkpoint_ns',
#    'checkpoint_id',
#    'parent_checkpoint_id',
#    'type',
#    'checkpoint',
#    'metadata']},
#  {'writes': ['thread_id',
#    'checkpoint_ns',
#    'checkpoint_id',
#    'task_id',
#    'idx',
#    'channel',
#    'type',
#    'value']}]

# %%
cursor.execute(f"select metadata from checkpoints")
metadata = cursor.fetchall()
metadata
# Out:
# [(b'{"source": "input", "step": -1, "parents": {}}',),
#  (b'{"source": "loop", "step": 0, "parents": {}}',),
#  (b'{"source": "loop", "step": 1, "parents": {}}',)]

# %%
steps = [json.loads(m[0]) for m in metadata]
steps
# Out:
# [{'source': 'input', 'step': -1, 'parents': {}},
#  {'source': 'loop', 'step': 0, 'parents': {}},
#  {'source': 'loop', 'step': 1, 'parents': {}}]
